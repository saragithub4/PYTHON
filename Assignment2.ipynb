# %% [markdown]
# List

# %%
#Create a list named age_list with five integer elements.
age_list=[24,25,26,27,28]
print (age_list)
# Out:
# [24, 25, 26, 27, 28]

# %%
#Create a list named name_list with five string elements.
name_list=["Ranjusha","Arun","Sain","Sara"]
print(name_list)
# Out:
# ['Ranjusha', 'Arun', 'Sain', 'Sara']

# %%
#Append the string "Yazhini" to name_list.
name_list.append("Yazhini")
print(name_list)
# Out:
# ['Ranjusha', 'Arun', 'Sain', 'Sara', 'Yazhini']

# %%
#Insert the element 30 at index 2 in age_list.
age_list.insert(2,30)
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 28]

# %%
#Remove the string "Yazhini" from name_list.
name_list.remove("Yazhini")
print(name_list)
# Out:
# ['Ranjusha', 'Arun', 'Sain', 'Sara']

# %%
#Pop the last element from age_list.
age_list.pop()
print (age_list)
# Out:
# [24, 25, 30, 26, 27]

# %%
#Extend the age_list with additional ages
age_list.extend([29,30,26])
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 29, 30, 26]

# %%
#Sort age_list in descending order.
age_list.sort(reverse=True)
print(age_list)
# Out:
# [30, 30, 29, 27, 26, 26, 25, 24]

# %%
#Find Max age, Min age and sum of all ages from age_list.
max_age = max(age_list)
min_age = min(age_list)
total_age = sum(age_list)

print("Maximum age:", max_age)
print("Minimum age:", min_age)
print("Sum of ages:", total_age)
# Out:
# Maximum age: 30
# Minimum age: 24
# Sum of ages: 217

# %%
#Print the first element of name_list.
print(name_list[0])
# Out:
# Ranjusha

# %%
#Print the last element of name_list.
print(name_list[-1])
# Out:
# Sara

# %%
#Print the elements from index 2 to index 4 in name_list.
print(name_list[2:5])
# Out:
# ['Sain', 'Sara']

# %%
#Print the elements of name_list in reverse order.
print(name_list[::-1])
# Out:
# ['Sara', 'Sain', 'Arun', 'Ranjusha']

# %% [markdown]
# List

# %%
#Create a dictionary named student_marks that maps the names of five students to their marks (use scale of from 0 to 100).
student_marks={"Ammu":80,"Miya":76,"Kiran":60,"Charan":78,"Lovely":65}
print(student_marks)
# Out:
# {'Ammu': 80, 'Miya': 76, 'Kiran': 60, 'Charan': 78, 'Lovely': 65}

# %%
#Access and print the mark of a specific student, of your choice.
print("Miya's mark:",student_marks["Miya"])
# Out:
# Miya's mark: 76

# %%
#Add a new student "Janani" with a mark of 80 to the student_marks dictionary.
student_marks["Janani"]=80
print(student_marks)
# Out:
# {'Ammu': 80, 'Miya': 76, 'Kiran': 60, 'Charan': 78, 'Lovely': 65, 'Janani': 80}

# %%
#Update the mark of any one older student to 82.
student_marks["Kiran"]=82
print (student_marks)
# Out:
# {'Ammu': 80, 'Miya': 76, 'Kiran': 82, 'Charan': 78, 'Lovely': 65, 'Janani': 80}

# %%
#Use the keys(), values(), and items() methods to print all keys, values, and key-value pairs in the student_marks dictionary.
print("Keys:",student_marks.keys())
print("Value:",student_marks.values())
print("Key value pairs:",student_marks.items())
# Out:
# Keys: dict_keys(['Ammu', 'Miya', 'Kiran', 'Charan', 'Lovely', 'Janani'])
# Value: dict_values([80, 76, 82, 78, 65, 80])
# Key value pairs: dict_items([('Ammu', 80), ('Miya', 76), ('Kiran', 82), ('Charan', 78), ('Lovely', 65), ('Janani', 80)])

# %% [markdown]
# SETS

# %%
#Create a set called my_set.
my_set={'a','e','i','o','u','a','a','i'}
print(my_set)
# Out:
# {'o', 'u', 'i', 'a', 'e'}

# %% [markdown]
# The set is an unordered collection so output appears in a different order. Also as set does not allow duplicate values, the duplicates are removedin the output.

# %%
#Attempt to change the value of my_set[4] = 's'. If code throws an error, provide an explanation.
my_set[4]='s'
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 #Attempt to change the value of my_set[4] = 's'. If code throws an error, provide an explanation.
# ----> 2 my_set[4]='s'
#       3 print(my_set)
#
# TypeError: 'set' object does not support item assignment

# %% [markdown]
# As set doesnot have index values, the elements cannot be modified using indexing.

# %%
#Create two sets: Compute and print the union and intersection of set1 and set2.
set1={1, 3, 5, 7, 9}
set2={2, 3, 5, 8, 10}
print(set1)
print(set2)
# Out:
# {1, 3, 5, 7, 9}
# {2, 3, 5, 8, 10}

# %%
union_set=set1.union(set2)
print(union_set)
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
intersection_set = set1.intersection(set2)
print(intersection_set)
# Out:
# {3, 5}

# %% [markdown]
# Operators & Conditional Statements

# %%
#Prompt user for Input. Score range should be from 0 to 10 (both inclusive).
score = float(input("Enter your score (0 to 10): "))

if score < 0 or score > 10:
    print("Invalid score. Please enter a score between 0 and 10.")

elif score > 7:
    print("Above Average: Excellent performance! Keep up the good work.")

elif score >= 4:
    print("Average: Good effort! Keep practicing, there's room for improvement.")

else:
    print("Below Average: Need to improve your performance. Consistent practice will lead to better results.")
# Out:
# Enter your score (0 to 10):  8
# Above Average: Excellent performance! Keep up the good work.
